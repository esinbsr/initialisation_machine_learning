# %% [markdown]
# <h2>Importation des bibliothèques</h2>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Lecture du fichier csv</h2>

# %%
train = pd.read_csv('train.csv')

# %% [markdown]
# <h2>Création d'une copie du fichier csv</h2>

# %%
train_copie = train.copy()

# %% [markdown]
# <i style="color:#90ADC6">-> je crée des copy des fichiers csv originaux car je ne veux pas écraser l'original.</p>

# %% [markdown]
# <h2>Affichage des données</h2>

# %%
pd.set_option('display.max_columns', None)
train_copie.head()

# %% [markdown]
# <h2>Vérification des valeurs nulles</h2>

# %%
train_copie.isnull().sum()

# %% [markdown]
# <i style="color:#90ADC6">->je vois qu'il y a des lignes en trop dans DueDate, LoanApplicationId, ThirdPartyId, et je trouve ça anormal, par exemple, pourquoi est-ce qu'il y a 614 dates limite du remboursement (DueDate) mais seulement 612 id de transaction de prêt (LoanId), il y a 2 lignes de trop ? </p>

# %%
train_null = train_copie[train_copie.isna().any(axis=1)]
train_null
# Out:
#           CustomerId TransactionStartTime   Value  Amount       TransactionId  \
# 0      CustomerId_27  2018-09-21 12:17:00   550.0  -550.0  TransactionId_1683
# 1      CustomerId_27  2018-09-25 09:20:00   550.0  -550.0  TransactionId_2235
# 2      CustomerId_27  2018-09-25 10:33:00   550.0  -550.0  TransactionId_1053
# 3      CustomerId_27  2018-09-27 10:26:00  1000.0 -1000.0  TransactionId_2633
# 4      CustomerId_27  2018-09-27 12:44:00   500.0  -500.0    TransactionId_71
# ...              ...                  ...     ...     ...                 ...
# 2071  CustomerId_133  2019-03-28 14:54:00   500.0  -500.0  TransactionId_1967
# 2080  CustomerId_133  2019-03-29 06:10:00   500.0  -500.0  TransactionId_1469
# 2084  CustomerId_133  2019-03-29 08:51:00   600.0  -600.0   TransactionId_387
# 2088  CustomerId_212  2019-03-29 15:35:00  1000.0 -1000.0  TransactionId_1572
# 2094  CustomerId_205  2019-03-30 17:12:00   500.0  -500.0  TransactionId_2547
#
#            BatchId    SubscriptionId CurrencyCode  CountryCode    ProviderId  \
# 0      BatchId_641  SubscriptionId_2          UGX          256  ProviderId_1
# 1      BatchId_820  SubscriptionId_2          UGX          256  ProviderId_1
# 2      BatchId_210  SubscriptionId_4          UGX          256  ProviderId_1
# 3      BatchId_876  SubscriptionId_4          UGX          256  ProviderId_1
# 4     BatchId_1362  SubscriptionId_4          UGX          256  ProviderId_1
# ...            ...               ...          ...          ...           ...
# 2071   BatchId_221  SubscriptionId_7          UGX          256  ProviderId_1
# 2080   BatchId_107  SubscriptionId_7          UGX          256  ProviderId_1
# 2084  BatchId_1466  SubscriptionId_7          UGX          256  ProviderId_1
# 2088  BatchId_2378  SubscriptionId_7          UGX          256  ProviderId_1
# 2094   BatchId_779  SubscriptionId_7          UGX          256  ProviderId_1
#
#         ProductId ProductCategory    ChannelId  TransactionStatus  \
# 0     ProductId_7         airtime  ChannelId_1                  0
# 1     ProductId_7         airtime  ChannelId_1                  0
# 2     ProductId_7         airtime  ChannelId_1                  0
# 3     ProductId_7         airtime  ChannelId_1                  0
# 4     ProductId_7         airtime  ChannelId_1                  0
# ...           ...             ...          ...                ...
# 2071  ProductId_3         airtime  ChannelId_1                  0
# 2080  ProductId_3         airtime  ChannelId_1                  0
# 2084  ProductId_3         airtime  ChannelId_1                  0
# 2088  ProductId_3         airtime  ChannelId_1                  0
# 2094  ProductId_4    data_bundles  ChannelId_1                  0
#
#      IssuedDateLoan  AmountLoan Currency LoanId PaidOnDate  IsFinalPayBack  \
# 0               NaT         NaN      NaN    NaN        NaT               0
# 1               NaT         NaN      NaN    NaN        NaT               0
# 2               NaT         NaN      NaN    NaN        NaT               0
# 3               NaT         NaN      NaN    NaN        NaT               0
# 4               NaT         NaN      NaN    NaN        NaT               0
# ...             ...         ...      ...    ...        ...             ...
# 2071            NaT         NaN      NaN    NaN        NaT               0
# 2080            NaT         NaN      NaN    NaN        NaT               0
# 2084            NaT         NaN      NaN    NaN        NaT               0
# 2088            NaT         NaN      NaN    NaN        NaT               0
# 2094            NaT         NaN      NaN    NaN        NaT               0
#
#      InvestorId DueDate LoanApplicationId PayBackId ThirdPartyId  \
# 0           NaN     NaT               NaN       NaN          NaN
# 1           NaN     NaT               NaN       NaN          NaN
# 2           NaN     NaT               NaN       NaN          NaN
# 3           NaN     NaT               NaN       NaN          NaN
# 4           NaN     NaT               NaN       NaN          NaN
# ...         ...     ...               ...       ...          ...
# 2071        NaN     NaT               NaN       NaN          NaN
# 2080        NaN     NaT               NaN       NaN          NaN
# 2084        NaN     NaT               NaN       NaN          NaN
# 2088        NaN     NaT               NaN       NaN          NaN
# 2094        NaN     NaT               NaN       NaN          NaN
#
#       IsThirdPartyConfirmed  IsDefaulted  days_late
# 0                         0            0        NaN
# 1                         0            0        NaN
# 2                         0            0        NaN
# 3                         0            0        NaN
# 4                         0            0        NaN
# ...                     ...          ...        ...
# 2071                      0            0        NaN
# 2080                      0            0        NaN
# 2084                      0            0        NaN
# 2088                      0            0        NaN
# 2094                      0            0        NaN
#
# [621 rows x 28 columns]

# %% [markdown]
# <i style="color:#90ADC6">->J'affiche les lignes qui ont au moins 1 "nan". Je vois que tous les gens qui ont un "nan" ont transactionstatus à 0, donc je vais explorer cette colonne.</p>

# %%
train_null['TransactionStatus'].value_counts()
# Out:
# TransactionStatus
# 0    612
# 1      9
# Name: count, dtype: int64

# %% [markdown]
# <i style="color:#90ADC6">->Je vois qu'il y a 9 valeurs à 1, donc 9 lignes avec un prêt, mais il manque des valeurs dans certaines colonnes. Je vais afficher ces 9 lignes suspects</p>

# %%
train_null.loc[train_null['TransactionStatus'] == 1]
# Out:
#           CustomerId TransactionStartTime     Value    Amount  \
# 9     CustomerId_258  2018-10-18 16:11:00   10000.0  -10000.0
# 10    CustomerId_258  2018-10-18 16:11:00   10000.0  -10000.0
# 11    CustomerId_258  2018-10-18 16:11:00   10000.0  -10000.0
# 13    CustomerId_233  2018-10-19 10:18:00    5150.0   -5150.0
# 14    CustomerId_233  2018-10-19 11:01:00     515.0    -515.0
# 954   CustomerId_369  2019-02-01 17:23:00    1000.0   -1000.0
# 1630  CustomerId_268  2019-02-27 12:46:00  192000.0 -192000.0
# 1795   CustomerId_14  2019-03-06 07:48:00  192000.0 -192000.0
# 2031  CustomerId_259  2019-03-22 16:45:00  100000.0 -100000.0
#
#            TransactionId       BatchId    SubscriptionId CurrencyCode  \
# 9     TransactionId_1041  BatchId_1970  SubscriptionId_4          UGX
# 10    TransactionId_1041  BatchId_1970  SubscriptionId_4          UGX
# 11    TransactionId_1041  BatchId_1970  SubscriptionId_4          UGX
# 13    TransactionId_1598  BatchId_1458  SubscriptionId_4          UGX
# 14    TransactionId_2115  BatchId_1672  SubscriptionId_4          UGX
# 954    TransactionId_712   BatchId_260  SubscriptionId_7          UGX
# 1630  TransactionId_2069  BatchId_1219  SubscriptionId_6          UGX
# 1795  TransactionId_1023  BatchId_1736  SubscriptionId_6          UGX
# 2031   TransactionId_370  BatchId_2290  SubscriptionId_1          UGX
#
#       CountryCode    ProviderId     ProductId ProductCategory    ChannelId  \
# 9             256  ProviderId_1   ProductId_7         airtime  ChannelId_1
# 10            256  ProviderId_1   ProductId_7         airtime  ChannelId_1
# 11            256  ProviderId_1   ProductId_7         airtime  ChannelId_1
# 13            256  ProviderId_1   ProductId_7         airtime  ChannelId_1
# 14            256  ProviderId_1   ProductId_7         airtime  ChannelId_1
# 954           256  ProviderId_1   ProductId_7         airtime  ChannelId_1
# 1630          256  ProviderId_1  ProductId_18          retail  ChannelId_1
# 1795          256  ProviderId_1  ProductId_18          retail  ChannelId_1
# 2031          256  ProviderId_1   ProductId_7         airtime  ChannelId_1
#
#       TransactionStatus      IssuedDateLoan  AmountLoan Currency       LoanId  \
# 9                     1 2018-10-18 16:11:00     10016.0      UGX    LoanId_62
# 10                    1 2018-10-18 16:11:00       584.0      UGX    LoanId_62
# 11                    1 2018-10-18 16:11:00       100.0      UGX    LoanId_62
# 13                    1 2018-10-19 10:18:00      5614.0      UGX    LoanId_22
# 14                    1 2018-10-19 11:01:00       544.0      UGX   LoanId_368
# 954                   1 2019-02-01 17:23:00      1055.0      UGX   LoanId_943
# 1630                  1 2019-02-27 12:46:00     71000.0      UGX   LoanId_604
# 1795                  1 2019-03-06 07:48:00    192000.0      UGX   LoanId_220
# 2031                  1 2019-03-22 16:45:00    110500.0      UGX  LoanId_1225
#
#               PaidOnDate  IsFinalPayBack    InvestorId             DueDate  \
# 9    2018-10-22 09:13:00               1  InvestorId_3 2018-11-17 16:11:00
# 10   2018-10-23 07:34:00               1  InvestorId_3 2018-11-17 16:11:00
# 11   2018-10-25 08:58:00               1  InvestorId_3 2018-11-17 16:11:00
# 13   2018-10-30 06:50:00               1  InvestorId_3 2018-11-18 10:16:00
# 14   2018-10-22 16:11:00               1  InvestorId_3 2018-11-18 11:00:00
# 954  2019-02-05 11:42:00               1  InvestorId_1                 NaT
# 1630 2019-04-05 12:16:00               1  InvestorId_2 2019-03-29 12:46:00
# 1795 2019-05-21 10:45:00               1  InvestorId_2 2019-04-05 07:48:00
# 2031 2019-04-04 19:36:00               1  InvestorId_2                 NaT
#
#            LoanApplicationId       PayBackId       ThirdPartyId  \
# 9                        NaN  PayBackId_1791   ThirdPartyId_648
# 10                       NaN  PayBackId_1067    ThirdPartyId_68
# 11                       NaN   PayBackId_928  ThirdPartyId_1883
# 13                       NaN   PayBackId_647  ThirdPartyId_1484
# 14                       NaN  PayBackId_1267   ThirdPartyId_949
# 954   LoanApplicationId_1085  PayBackId_1045  ThirdPartyId_1317
# 1630  LoanApplicationId_1251     PayBackId_3                NaN
# 1795   LoanApplicationId_590  PayBackId_2024                NaN
# 2031   LoanApplicationId_813  PayBackId_1170  ThirdPartyId_1904
#
#       IsThirdPartyConfirmed  IsDefaulted  days_late
# 9                         0            0      -27.0
# 10                        0            0      -26.0
# 11                        0            0      -24.0
# 13                        0            0      -20.0
# 14                        0            0      -27.0
# 954                       1            0        NaN
# 1630                      1            1        6.0
# 1795                      1            1       46.0
# 2031                      1            0        NaN

# %% [markdown]
# <i style="color:#90ADC6">->Parmis les 9 lignes affichés, je vois le CustomerId_258, donc je vais aller voir toutes les lignes concernant cet id pour essayer de comprendre."</p>

# %%
train_copie[train_copie['CustomerId'] == "CustomerId_258"]
# Out:
#           CustomerId TransactionStartTime     Value    Amount  \
# 9     CustomerId_258  2018-10-18 16:11:00   10000.0  -10000.0
# 10    CustomerId_258  2018-10-18 16:11:00   10000.0  -10000.0
# 11    CustomerId_258  2018-10-18 16:11:00   10000.0  -10000.0
# 34    CustomerId_258  2018-11-01 15:23:00   10000.0  -10000.0
# 80    CustomerId_258  2018-11-09 18:07:00   10000.0  -10000.0
# 82    CustomerId_258  2018-11-10 20:19:00    5000.0   -5000.0
# 143   CustomerId_258  2018-11-24 16:06:00   30000.0  -30000.0
# 144   CustomerId_258  2018-11-24 16:06:00   30000.0  -30000.0
# 335   CustomerId_258  2018-12-10 17:10:00    5000.0   -5000.0
# 603   CustomerId_258  2019-01-03 12:08:00   50000.0  -50000.0
# 667   CustomerId_258  2019-01-10 16:06:00    5000.0   -5000.0
# 973   CustomerId_258  2019-02-03 07:09:00  118450.0 -115000.0
# 1086  CustomerId_258  2019-02-07 16:28:00   61800.0  -60000.0
# 1693  CustomerId_258  2019-03-03 09:02:00   10000.0  -10000.0
# 1694  CustomerId_258  2019-03-03 09:20:00   20000.0  -20000.0
# 2004  CustomerId_258  2019-03-20 11:40:00   10000.0  -10000.0
# 2083  CustomerId_258  2019-03-29 08:13:00   10000.0  -10000.0
#
#            TransactionId       BatchId    SubscriptionId CurrencyCode  \
# 9     TransactionId_1041  BatchId_1970  SubscriptionId_4          UGX
# 10    TransactionId_1041  BatchId_1970  SubscriptionId_4          UGX
# 11    TransactionId_1041  BatchId_1970  SubscriptionId_4          UGX
# 34     TransactionId_710  BatchId_1930  SubscriptionId_1          UGX
# 80    TransactionId_1979   BatchId_681  SubscriptionId_1          UGX
# 82     TransactionId_605  BatchId_1689  SubscriptionId_1          UGX
# 143     TransactionId_73   BatchId_137  SubscriptionId_1          UGX
# 144     TransactionId_73   BatchId_137  SubscriptionId_1          UGX
# 335    TransactionId_319    BatchId_23  SubscriptionId_1          UGX
# 603    TransactionId_724  BatchId_1045  SubscriptionId_1          UGX
# 667    TransactionId_933  BatchId_1174  SubscriptionId_1          UGX
# 973    TransactionId_109  BatchId_1377  SubscriptionId_1          UGX
# 1086   TransactionId_189    BatchId_68  SubscriptionId_1          UGX
# 1693  TransactionId_2327   BatchId_504  SubscriptionId_1          UGX
# 1694   TransactionId_847    BatchId_82  SubscriptionId_1          UGX
# 2004  TransactionId_1403   BatchId_285  SubscriptionId_1          UGX
# 2083  TransactionId_2464   BatchId_417  SubscriptionId_1          UGX
#
#       CountryCode    ProviderId    ProductId ProductCategory    ChannelId  \
# 9             256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 10            256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 11            256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 34            256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 80            256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 82            256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 143           256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 144           256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 335           256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 603           256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 667           256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 973           256  ProviderId_1  ProductId_5              tv  ChannelId_1
# 1086          256  ProviderId_1  ProductId_5              tv  ChannelId_1
# 1693          256  ProviderId_1  ProductId_8    data_bundles  ChannelId_1
# 1694          256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 2004          256  ProviderId_1  ProductId_7         airtime  ChannelId_1
# 2083          256  ProviderId_1  ProductId_3         airtime  ChannelId_1
#
#       TransactionStatus      IssuedDateLoan  AmountLoan Currency       LoanId  \
# 9                     1 2018-10-18 16:11:00     10016.0      UGX    LoanId_62
# 10                    1 2018-10-18 16:11:00       584.0      UGX    LoanId_62
# 11                    1 2018-10-18 16:11:00       100.0      UGX    LoanId_62
# 34                    1 2018-11-01 15:23:00     11100.0      UGX   LoanId_430
# 80                    1 2018-11-09 18:07:00     10700.0      UGX  LoanId_1601
# 82                    1 2018-11-10 20:19:00      5325.0      UGX   LoanId_697
# 143                   1 2018-11-24 16:06:00     20000.0      UGX  LoanId_1268
# 144                   1 2018-11-24 16:06:00     14650.0      UGX  LoanId_1268
# 335                   1 2018-12-10 17:10:00      5200.0      UGX   LoanId_349
# 603                   1 2019-01-03 12:07:00     58500.0      UGX  LoanId_1294
# 667                   1 2019-01-10 16:06:00      5200.0      UGX   LoanId_589
# 973                   1 2019-02-03 07:09:00    158314.0      UGX   LoanId_926
# 1086                  1 2019-02-07 16:27:00     77795.0      UGX  LoanId_1380
# 1693                  1 2019-03-03 09:02:00     10750.0      UGX   LoanId_101
# 1694                  1 2019-03-03 09:20:00     21500.0      UGX   LoanId_290
# 2004                  1 2019-03-20 11:40:00     10700.0      UGX  LoanId_1392
# 2083                  1 2019-03-29 08:13:00     11950.0      UGX   LoanId_127
#
#               PaidOnDate  IsFinalPayBack    InvestorId             DueDate  \
# 9    2018-10-22 09:13:00               1  InvestorId_3 2018-11-17 16:11:00
# 10   2018-10-23 07:34:00               1  InvestorId_3 2018-11-17 16:11:00
# 11   2018-10-25 08:58:00               1  InvestorId_3 2018-11-17 16:11:00
# 34   2018-11-16 12:22:00               1  InvestorId_2 2018-12-01 15:23:00
# 80   2018-11-16 12:22:00               1  InvestorId_2 2018-12-09 18:07:00
# 82   2018-11-16 12:23:00               1  InvestorId_2 2018-12-10 20:19:00
# 143  2018-12-14 08:37:00               0  InvestorId_2 2018-12-24 16:05:00
# 144  2018-12-18 11:49:00               1  InvestorId_2 2018-12-24 16:05:00
# 335  2018-12-10 17:18:00               1  InvestorId_2 2019-01-09 17:10:00
# 603  2019-01-29 13:37:00               1  InvestorId_2 2019-02-02 12:07:00
# 667  2019-01-10 16:07:00               1  InvestorId_2 2019-02-09 16:06:00
# 973  2019-03-27 05:41:00               1  InvestorId_2 2019-03-05 07:09:00
# 1086 2019-03-11 07:25:00               1  InvestorId_2 2019-03-09 16:27:00
# 1693 2019-03-11 07:24:00               1  InvestorId_2 2019-04-02 09:02:00
# 1694 2019-03-11 07:20:00               1  InvestorId_2 2019-04-02 09:20:00
# 2004 2019-03-27 05:42:00               1  InvestorId_2 2019-04-19 11:40:00
# 2083 2019-04-29 09:52:00               1  InvestorId_2 2019-04-28 08:13:00
#
#            LoanApplicationId       PayBackId       ThirdPartyId  \
# 9                        NaN  PayBackId_1791   ThirdPartyId_648
# 10                       NaN  PayBackId_1067    ThirdPartyId_68
# 11                       NaN   PayBackId_928  ThirdPartyId_1883
# 34    LoanApplicationId_1394   PayBackId_654  ThirdPartyId_1180
# 80     LoanApplicationId_374  PayBackId_1133   ThirdPartyId_136
# 82    LoanApplicationId_1349   PayBackId_532   ThirdPartyId_999
# 143    LoanApplicationId_833  PayBackId_1515   ThirdPartyId_891
# 144    LoanApplicationId_833  PayBackId_1929  ThirdPartyId_1993
# 335   LoanApplicationId_1195  PayBackId_1970  ThirdPartyId_1654
# 603   LoanApplicationId_1511  PayBackId_1941  ThirdPartyId_1889
# 667   LoanApplicationId_1513  PayBackId_2003   ThirdPartyId_153
# 973   LoanApplicationId_1455   PayBackId_686   ThirdPartyId_442
# 1086  LoanApplicationId_1217  PayBackId_1042   ThirdPartyId_491
# 1693   LoanApplicationId_588  PayBackId_1117  ThirdPartyId_1750
# 1694  LoanApplicationId_1015   PayBackId_519  ThirdPartyId_1684
# 2004   LoanApplicationId_211  PayBackId_1079   ThirdPartyId_953
# 2083  LoanApplicationId_1035  PayBackId_1044   ThirdPartyId_550
#
#       IsThirdPartyConfirmed  IsDefaulted  days_late
# 9                         0            0      -27.0
# 10                        0            0      -26.0
# 11                        0            0      -24.0
# 34                        1            0      -16.0
# 80                        1            0      -24.0
# 82                        1            0      -25.0
# 143                       1            0      -11.0
# 144                       1            0       -7.0
# 335                       1            0      -30.0
# 603                       1            0       -4.0
# 667                       1            0      -30.0
# 973                       1            0       21.0
# 1086                      1            0        1.0
# 1693                      1            0      -23.0
# 1694                      1            0      -23.0
# 2004                      1            0      -24.0
# 2083                      1            0        1.0

# %% [markdown]
# <h2>Modifications des types de données incorrectes</h2>

# %%
train_copie[['TransactionStartTime', 'IssuedDateLoan', 'PaidOnDate', 'DueDate']] = train_copie[['TransactionStartTime', 'IssuedDateLoan', 'PaidOnDate', 'DueDate']].apply(pd.to_datetime, errors='coerce')
train_copie[['TransactionStatus', 'IsFinalPayBack', 'IsThirdPartyConfirmed', 'IsDefaulted']] = train_copie[['TransactionStatus', 'IsFinalPayBack', 'IsThirdPartyConfirmed', 'IsDefaulted']].fillna(0).astype(int)

# %% [markdown]
# <i style="color:#90ADC6">-> Après une analyse des types de données, je vois que certaines colonnes n'ont pas le bon type de données, donc je les convertis.</p>

# %% [markdown]
# <h2>Affichage des clients avec un retard de paiement</h2>

# %%
train_copie['days_late'] = (train_copie['PaidOnDate'] - train_copie['DueDate']).dt.days
train_copie
# Out:
#           CustomerId TransactionStartTime   Value  Amount       TransactionId  \
# 0      CustomerId_27  2018-09-21 12:17:00   550.0  -550.0  TransactionId_1683
# 1      CustomerId_27  2018-09-25 09:20:00   550.0  -550.0  TransactionId_2235
# 2      CustomerId_27  2018-09-25 10:33:00   550.0  -550.0  TransactionId_1053
# 3      CustomerId_27  2018-09-27 10:26:00  1000.0 -1000.0  TransactionId_2633
# 4      CustomerId_27  2018-09-27 12:44:00   500.0  -500.0    TransactionId_71
# ...              ...                  ...     ...     ...                 ...
# 2095   CustomerId_28  2019-03-30 21:55:00  2000.0 -2000.0  TransactionId_1185
# 2096   CustomerId_28  2019-03-30 23:54:00  5000.0 -5000.0  TransactionId_1824
# 2097   CustomerId_34  2019-03-31 05:40:00  5000.0 -5000.0  TransactionId_2507
# 2098  CustomerId_346  2019-03-31 09:37:00  1500.0 -1500.0   TransactionId_540
# 2099  CustomerId_188  2019-03-31 12:16:00  1000.0 -1000.0  TransactionId_1889
#
#            BatchId    SubscriptionId CurrencyCode  CountryCode    ProviderId  \
# 0      BatchId_641  SubscriptionId_2          UGX          256  ProviderId_1
# 1      BatchId_820  SubscriptionId_2          UGX          256  ProviderId_1
# 2      BatchId_210  SubscriptionId_4          UGX          256  ProviderId_1
# 3      BatchId_876  SubscriptionId_4          UGX          256  ProviderId_1
# 4     BatchId_1362  SubscriptionId_4          UGX          256  ProviderId_1
# ...            ...               ...          ...          ...           ...
# 2095  BatchId_2069  SubscriptionId_7          UGX          256  ProviderId_1
# 2096  BatchId_1552  SubscriptionId_7          UGX          256  ProviderId_1
# 2097  BatchId_1093  SubscriptionId_7          UGX          256  ProviderId_1
# 2098  BatchId_1239  SubscriptionId_7          UGX          256  ProviderId_1
# 2099   BatchId_355  SubscriptionId_7          UGX          256  ProviderId_1
#
#         ProductId ProductCategory    ChannelId  TransactionStatus  \
# 0     ProductId_7         airtime  ChannelId_1                  0
# 1     ProductId_7         airtime  ChannelId_1                  0
# 2     ProductId_7         airtime  ChannelId_1                  0
# 3     ProductId_7         airtime  ChannelId_1                  0
# 4     ProductId_7         airtime  ChannelId_1                  0
# ...           ...             ...          ...                ...
# 2095  ProductId_8    data_bundles  ChannelId_1                  1
# 2096  ProductId_7         airtime  ChannelId_1                  1
# 2097  ProductId_3         airtime  ChannelId_1                  1
# 2098  ProductId_8    data_bundles  ChannelId_1                  1
# 2099  ProductId_3         airtime  ChannelId_1                  1
#
#           IssuedDateLoan  AmountLoan Currency       LoanId  \
# 0                    NaT         NaN      NaN          NaN
# 1                    NaT         NaN      NaN          NaN
# 2                    NaT         NaN      NaN          NaN
# 3                    NaT         NaN      NaN          NaN
# 4                    NaT         NaN      NaN          NaN
# ...                  ...         ...      ...          ...
# 2095 2019-03-30 21:55:00      2370.0      UGX   LoanId_293
# 2096 2019-03-30 23:54:00      5925.0      UGX  LoanId_1040
# 2097 2019-03-31 05:40:00      7100.0      UGX  LoanId_1585
# 2098 2019-03-31 09:37:00      1733.0      UGX  LoanId_1314
# 2099 2019-03-31 12:16:00      1090.0      UGX  LoanId_1570
#
#               PaidOnDate  IsFinalPayBack    InvestorId             DueDate  \
# 0                    NaT               0           NaN                 NaT
# 1                    NaT               0           NaN                 NaT
# 2                    NaT               0           NaN                 NaT
# 3                    NaT               0           NaN                 NaT
# 4                    NaT               0           NaN                 NaT
# ...                  ...             ...           ...                 ...
# 2095 2019-04-29 14:35:00               1  InvestorId_1 2019-04-29 21:55:00
# 2096 2019-04-29 14:32:00               1  InvestorId_1 2019-04-29 23:53:00
# 2097 2019-06-15 06:20:00               1  InvestorId_1 2019-04-30 05:40:00
# 2098 2019-04-23 15:44:00               1  InvestorId_1 2019-04-30 09:37:00
# 2099 2019-04-10 17:33:00               1  InvestorId_1 2019-04-30 12:16:00
#
#            LoanApplicationId       PayBackId       ThirdPartyId  \
# 0                        NaN             NaN                NaN
# 1                        NaN             NaN                NaN
# 2                        NaN             NaN                NaN
# 3                        NaN             NaN                NaN
# 4                        NaN             NaN                NaN
# ...                      ...             ...                ...
# 2095   LoanApplicationId_524  PayBackId_1106   ThirdPartyId_857
# 2096  LoanApplicationId_1441   PayBackId_966   ThirdPartyId_958
# 2097  LoanApplicationId_1466  PayBackId_1271  ThirdPartyId_1981
# 2098  LoanApplicationId_1389   PayBackId_945   ThirdPartyId_705
# 2099    LoanApplicationId_57   PayBackId_830   ThirdPartyId_899
#
#       IsThirdPartyConfirmed  IsDefaulted  days_late
# 0                         0            0        NaN
# 1                         0            0        NaN
# 2                         0            0        NaN
# 3                         0            0        NaN
# 4                         0            0        NaN
# ...                     ...          ...        ...
# 2095                      1            0       -1.0
# 2096                      1            0       -1.0
# 2097                      1            0       46.0
# 2098                      1            0       -7.0
# 2099                      1            0      -20.0
#
# [2100 rows x 28 columns]

# %% [markdown]
# <i style="color:#90ADC6">->Ici, je crée une nouvelle colonne qui affiche le nombre de jour en retard ou non d'un remboursement de prêt. </p>

# %%
retard_paiement = train_copie[train_copie['days_late'] > 0]
retard_paiement
# Out:
#           CustomerId TransactionStartTime    Value   Amount  \
# 26    CustomerId_474  2018-10-26 09:19:00  10000.0 -10000.0
# 28    CustomerId_432  2018-10-26 16:12:00  31766.0 -30840.0
# 35    CustomerId_405  2018-11-01 16:12:00  53500.0 -50000.0
# 36    CustomerId_405  2018-11-01 16:12:00  53500.0 -50000.0
# 37    CustomerId_474  2018-11-01 17:56:00   5000.0  -5000.0
# ...              ...                  ...      ...      ...
# 2079  CustomerId_180  2019-03-29 04:43:00   5000.0  -5000.0
# 2081  CustomerId_180  2019-03-29 06:15:00   4000.0  -4000.0
# 2083  CustomerId_258  2019-03-29 08:13:00  10000.0 -10000.0
# 2087  CustomerId_502  2019-03-29 14:43:00   2000.0  -2000.0
# 2097   CustomerId_34  2019-03-31 05:40:00   5000.0  -5000.0
#
#            TransactionId       BatchId    SubscriptionId CurrencyCode  \
# 26    TransactionId_2299   BatchId_500  SubscriptionId_1          UGX
# 28    TransactionId_2128   BatchId_381  SubscriptionId_1          UGX
# 35     TransactionId_549  BatchId_2426  SubscriptionId_1          UGX
# 36     TransactionId_549  BatchId_2426  SubscriptionId_1          UGX
# 37    TransactionId_1452   BatchId_728  SubscriptionId_1          UGX
# ...                  ...           ...               ...          ...
# 2079  TransactionId_1575   BatchId_359  SubscriptionId_7          UGX
# 2081  TransactionId_1010   BatchId_614  SubscriptionId_7          UGX
# 2083  TransactionId_2464   BatchId_417  SubscriptionId_1          UGX
# 2087   TransactionId_309   BatchId_777  SubscriptionId_5          UGX
# 2097  TransactionId_2507  BatchId_1093  SubscriptionId_7          UGX
#
#       CountryCode    ProviderId     ProductId ProductCategory    ChannelId  \
# 26            256  ProviderId_1   ProductId_7         airtime  ChannelId_1
# 28            256  ProviderId_1   ProductId_6              tv  ChannelId_1
# 35            256  ProviderId_1  ProductId_15    utility_bill  ChannelId_1
# 36            256  ProviderId_1  ProductId_15    utility_bill  ChannelId_1
# 37            256  ProviderId_1   ProductId_3         airtime  ChannelId_1
# ...           ...           ...           ...             ...          ...
# 2079          256  ProviderId_1   ProductId_1         airtime  ChannelId_1
# 2081          256  ProviderId_1   ProductId_3         airtime  ChannelId_1
# 2083          256  ProviderId_1   ProductId_3         airtime  ChannelId_1
# 2087          256  ProviderId_1   ProductId_3         airtime  ChannelId_1
# 2097          256  ProviderId_1   ProductId_3         airtime  ChannelId_1
#
#       TransactionStatus      IssuedDateLoan  AmountLoan Currency       LoanId  \
# 26                    1 2018-10-26 09:19:00     10000.0      UGX   LoanId_934
# 28                    1 2018-10-26 16:12:00     30840.0      UGX   LoanId_386
# 35                    1 2018-11-01 16:12:00     63398.0      UGX    LoanId_77
# 36                    1 2018-11-01 16:12:00      2942.0      UGX    LoanId_77
# 37                    1 2018-11-01 17:56:00       500.0      UGX  LoanId_1554
# ...                 ...                 ...         ...      ...          ...
# 2079                  1 2019-03-29 04:43:00      6325.0      UGX   LoanId_409
# 2081                  1 2019-03-29 06:15:00      4860.0      UGX   LoanId_247
# 2083                  1 2019-03-29 08:13:00     11950.0      UGX   LoanId_127
# 2087                  1 2019-03-29 14:43:00      2550.0      UGX   LoanId_848
# 2097                  1 2019-03-31 05:40:00      7100.0      UGX  LoanId_1585
#
#               PaidOnDate  IsFinalPayBack    InvestorId             DueDate  \
# 26   2019-05-16 07:25:00               1  InvestorId_2 2018-11-25 09:18:00
# 28   2019-04-26 16:24:00               1  InvestorId_2 2018-11-25 16:12:00
# 35   2018-12-06 09:26:00               0  InvestorId_2 2018-12-01 16:12:00
# 36   2018-12-11 17:00:00               1  InvestorId_2 2018-12-01 16:12:00
# 37   2019-07-15 09:12:00               0  InvestorId_2 2018-12-01 17:56:00
# ...                  ...             ...           ...                 ...
# 2079 2019-05-13 09:33:00               1  InvestorId_1 2019-04-28 04:43:00
# 2081 2019-05-03 18:31:00               1  InvestorId_1 2019-04-28 06:15:00
# 2083 2019-04-29 09:52:00               1  InvestorId_2 2019-04-28 08:13:00
# 2087 2019-05-16 08:04:00               1  InvestorId_2 2019-04-28 14:43:00
# 2097 2019-06-15 06:20:00               1  InvestorId_1 2019-04-30 05:40:00
#
#            LoanApplicationId       PayBackId       ThirdPartyId  \
# 26     LoanApplicationId_164  PayBackId_1899   ThirdPartyId_601
# 28     LoanApplicationId_836  PayBackId_1262  ThirdPartyId_1546
# 35     LoanApplicationId_534   PayBackId_165  ThirdPartyId_1760
# 36     LoanApplicationId_534  PayBackId_1908  ThirdPartyId_1716
# 37     LoanApplicationId_937  PayBackId_1295  ThirdPartyId_1702
# ...                      ...             ...                ...
# 2079  LoanApplicationId_1610   PayBackId_187  ThirdPartyId_1891
# 2081   LoanApplicationId_747   PayBackId_246   ThirdPartyId_607
# 2083  LoanApplicationId_1035  PayBackId_1044   ThirdPartyId_550
# 2087   LoanApplicationId_252   PayBackId_151   ThirdPartyId_646
# 2097  LoanApplicationId_1466  PayBackId_1271  ThirdPartyId_1981
#
#       IsThirdPartyConfirmed  IsDefaulted  days_late
# 26                        0            1      171.0
# 28                        1            0      152.0
# 35                        1            0        4.0
# 36                        1            0       10.0
# 37                        1            1      225.0
# ...                     ...          ...        ...
# 2079                      1            0       15.0
# 2081                      1            0        5.0
# 2083                      1            0        1.0
# 2087                      0            0       17.0
# 2097                      1            0       46.0
#
# [407 rows x 28 columns]

# %% [markdown]
# <i style="color:#90ADC6">-> Ici je vois que certaines lignes ont dépasser le délais de paiement mais IsDefaulted est à 0, ce qui est illogique car il est censé être à 1 puisque ils n'ont pas payé à temps.</p>

# %%
#afficher les lignes qui ont un retard de paiement mais qui sont pas en defaut IsDefaulted (0)
train_copie.loc[(train_copie['IsDefaulted'] == 0) & (train_copie['PaidOnDate'] > train_copie['DueDate'])]
# Out:
#           CustomerId TransactionStartTime    Value   Amount  \
# 28    CustomerId_432  2018-10-26 16:12:00  31766.0 -30840.0
# 35    CustomerId_405  2018-11-01 16:12:00  53500.0 -50000.0
# 36    CustomerId_405  2018-11-01 16:12:00  53500.0 -50000.0
# 40    CustomerId_233  2018-11-02 06:53:00    500.0   -500.0
# 41    CustomerId_233  2018-11-02 07:07:00    500.0   -500.0
# ...              ...                  ...      ...      ...
# 2081  CustomerId_180  2019-03-29 06:15:00   4000.0  -4000.0
# 2083  CustomerId_258  2019-03-29 08:13:00  10000.0 -10000.0
# 2087  CustomerId_502  2019-03-29 14:43:00   2000.0  -2000.0
# 2092  CustomerId_282  2019-03-29 19:38:00   5000.0  -5000.0
# 2097   CustomerId_34  2019-03-31 05:40:00   5000.0  -5000.0
#
#            TransactionId       BatchId    SubscriptionId CurrencyCode  \
# 28    TransactionId_2128   BatchId_381  SubscriptionId_1          UGX
# 35     TransactionId_549  BatchId_2426  SubscriptionId_1          UGX
# 36     TransactionId_549  BatchId_2426  SubscriptionId_1          UGX
# 40    TransactionId_1863  BatchId_2428  SubscriptionId_1          UGX
# 41     TransactionId_598  BatchId_1579  SubscriptionId_1          UGX
# ...                  ...           ...               ...          ...
# 2081  TransactionId_1010   BatchId_614  SubscriptionId_7          UGX
# 2083  TransactionId_2464   BatchId_417  SubscriptionId_1          UGX
# 2087   TransactionId_309   BatchId_777  SubscriptionId_5          UGX
# 2092   TransactionId_592    BatchId_88  SubscriptionId_7          UGX
# 2097  TransactionId_2507  BatchId_1093  SubscriptionId_7          UGX
#
#       CountryCode    ProviderId     ProductId ProductCategory    ChannelId  \
# 28            256  ProviderId_1   ProductId_6              tv  ChannelId_1
# 35            256  ProviderId_1  ProductId_15    utility_bill  ChannelId_1
# 36            256  ProviderId_1  ProductId_15    utility_bill  ChannelId_1
# 40            256  ProviderId_1   ProductId_7         airtime  ChannelId_1
# 41            256  ProviderId_1  ProductId_17          movies  ChannelId_1
# ...           ...           ...           ...             ...          ...
# 2081          256  ProviderId_1   ProductId_3         airtime  ChannelId_1
# 2083          256  ProviderId_1   ProductId_3         airtime  ChannelId_1
# 2087          256  ProviderId_1   ProductId_3         airtime  ChannelId_1
# 2092          256  ProviderId_1   ProductId_7         airtime  ChannelId_1
# 2097          256  ProviderId_1   ProductId_3         airtime  ChannelId_1
#
#       TransactionStatus      IssuedDateLoan  AmountLoan Currency       LoanId  \
# 28                    1 2018-10-26 16:12:00     30840.0      UGX   LoanId_386
# 35                    1 2018-11-01 16:12:00     63398.0      UGX    LoanId_77
# 36                    1 2018-11-01 16:12:00      2942.0      UGX    LoanId_77
# 40                    1 2018-11-02 06:53:00       633.0      UGX   LoanId_566
# 41                    1 2018-11-02 07:07:00       633.0      UGX  LoanId_1291
# ...                 ...                 ...         ...      ...          ...
# 2081                  1 2019-03-29 06:15:00      4860.0      UGX   LoanId_247
# 2083                  1 2019-03-29 08:13:00     11950.0      UGX   LoanId_127
# 2087                  1 2019-03-29 14:43:00      2550.0      UGX   LoanId_848
# 2092                  1 2019-03-29 19:38:00      5950.0      UGX   LoanId_254
# 2097                  1 2019-03-31 05:40:00      7100.0      UGX  LoanId_1585
#
#               PaidOnDate  IsFinalPayBack    InvestorId             DueDate  \
# 28   2019-04-26 16:24:00               1  InvestorId_2 2018-11-25 16:12:00
# 35   2018-12-06 09:26:00               0  InvestorId_2 2018-12-01 16:12:00
# 36   2018-12-11 17:00:00               1  InvestorId_2 2018-12-01 16:12:00
# 40   2018-12-17 15:00:00               1  InvestorId_2 2018-12-02 06:53:00
# 41   2018-12-17 15:01:00               1  InvestorId_2 2018-12-02 07:07:00
# ...                  ...             ...           ...                 ...
# 2081 2019-05-03 18:31:00               1  InvestorId_1 2019-04-28 06:15:00
# 2083 2019-04-29 09:52:00               1  InvestorId_2 2019-04-28 08:13:00
# 2087 2019-05-16 08:04:00               1  InvestorId_2 2019-04-28 14:43:00
# 2092 2019-04-29 09:16:00               1  InvestorId_1 2019-04-28 19:38:00
# 2097 2019-06-15 06:20:00               1  InvestorId_1 2019-04-30 05:40:00
#
#            LoanApplicationId       PayBackId       ThirdPartyId  \
# 28     LoanApplicationId_836  PayBackId_1262  ThirdPartyId_1546
# 35     LoanApplicationId_534   PayBackId_165  ThirdPartyId_1760
# 36     LoanApplicationId_534  PayBackId_1908  ThirdPartyId_1716
# 40       LoanApplicationId_2   PayBackId_719   ThirdPartyId_310
# 41    LoanApplicationId_1385  PayBackId_1198  ThirdPartyId_1073
# ...                      ...             ...                ...
# 2081   LoanApplicationId_747   PayBackId_246   ThirdPartyId_607
# 2083  LoanApplicationId_1035  PayBackId_1044   ThirdPartyId_550
# 2087   LoanApplicationId_252   PayBackId_151   ThirdPartyId_646
# 2092  LoanApplicationId_1467  PayBackId_1152  ThirdPartyId_1703
# 2097  LoanApplicationId_1466  PayBackId_1271  ThirdPartyId_1981
#
#       IsThirdPartyConfirmed  IsDefaulted  days_late
# 28                        1            0      152.0
# 35                        1            0        4.0
# 36                        1            0       10.0
# 40                        1            0       15.0
# 41                        1            0       15.0
# ...                     ...          ...        ...
# 2081                      1            0        5.0
# 2083                      1            0        1.0
# 2087                      0            0       17.0
# 2092                      1            0        0.0
# 2097                      1            0       46.0
#
# [341 rows x 28 columns]

# %% [markdown]
# <i style="color:#90ADC6"> ->Ici, je m'apperçois qu'il y a 341 anomalies. Ils sont pas en défaut mais ont un retard de paiement.  </p>

# %%
#on veut etre sur que le isdefaulted s'applique au personne qui ont pas fini de payer
#besoin de isdefaulted et isfinalpayback

# %% [markdown]
# <h2>Vérification des corélations entre les colonnes</h2>

# %%
pearson_corr = pret_complet.select_dtypes(include=['int64', 'float']).corr(method='pearson')
pearson_corr

# %%
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm')
plt.title("Pearson Correlation Heatmap")
plt.show()
